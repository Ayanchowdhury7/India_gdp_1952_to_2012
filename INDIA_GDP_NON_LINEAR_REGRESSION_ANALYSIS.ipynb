# %% [markdown]
# # <center>Non Linear Regression Analysis</center>

# %% [markdown]
# If the data shows a curvy trend, then linear regression will not produce very accurate results when compared to a non-linear regressio because, as the name implies, linear regression presumes that the data is linear. Let's learn about the non linear regressions and apply an example on Python. In this note book, we fit a non-linear model to the datapoints corresponding to India's GDP.

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Though Linear regression is very good to solve many problems, it can not be used for all datasets. First recall how linear regression, could  model a dataset. It models a linear relation between a dependent variable y and independent variable x. It had a simple equation, of dgree 1, for example y = 2*(x)+3

# %%
x = np.arange(-5.0,5.0,1)

# You can adjust the slope and intercept to verify the changes in the graph
y = 2 * (x) + 3
y_noise = 2 * np.random.normal(size = x.size)
y_data = y + y_noise

# Plot figure
plt.plot(x, y_data, 'bo')
plt.plot(x, y, 'r')
plt.xlabel('Independent variable')
plt.ylabel('Dependent variable')
plt.show()

# %% [markdown]
# Non-linear regressions are a relationship between independent variables $x$ and a dependent variable $y$ which result in a non-linear function modeled data. Essentially any relationship that is not linear can be termed as non-linear, and is usually represented by the polynomial of $k$ degrees (maximum power of $x$).
#
# $$ \ y = a x^3 + b x^2 + c x + d \ $$
#
# Non-linear functions can have elements like exponentials, logarithms, fractions, and others. For example: $$ y = \log(x)$$
#
# Or even, more complicated such as :
# $$ y = \log(a x^3 + b x^2 + c x + d)$$

# %% [markdown]
# ### Cubic
#
# $$ y = ax^3 + bx^3+cx+d $$

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Quadratic
#
# $$ y = x^2 $$

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Exponential
#
# An exponential function with base c is defined by $$ Y = a + b c^X$$ where b ≠0, c > 0 , c ≠1, and x is any real number. The base, c, is constant and the exponent, x, is a variable.

# %%
X = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

Y = 2 * np.exp(3 * X) + 4

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Logarithmic
#
# The response $y$ is a results of applying logarithmic map from input $x$'s to output variable $y$. It is one of the simplest form of __log()__: i.e. $$ y = \log(x)$$
#
# Please consider that instead of $x$, we can use $X$, which can be polynomial representation of the $x$'s. In general form it would be written as
# \begin{equation}
# y = \log(X)
# \end{equation}

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Sigmoidal/Logistic
#
# $$ Y = a + \frac{b}{1+ c^{(X-d)}}$$

# %%
X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ## Non-Linear Regression example
#
# For an example, we're going to try and fit a non-linear model to the datapoints corresponding to India's GDP from .

# %%
import numpy as np
import pandas as pd

path = "/home/ice_bear/work_csv_files/india_gdp.csv"

df = pd. read_csv(path)
df
# Out:
#    Financial Year  Gross Domestic Product (in Rs. Cr) at 2004-05 Prices  \
# 0         1951-52                                             286147
# 1         1952-53                                             294267
# 2         1953-54                                             312177
# 3         1954-55                                             325431
# 4         1955-56                                             333766
# ..            ...                                                ...
# 56        2007-08                                            3896636
# 57        2008-09                                            4158676
# 58        2009-10                                            4516071
# 59        2010-11                                            4937006
# 60        2011-12                                            5243582
#
#     Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                              147216
# ...

# %%
df.columns
# Out:
# Index(['Financial Year',
#        'Gross Domestic Product (in Rs. Cr) at 2004-05 Prices',
#        'Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices',
#        'Agriculture (in Rs. Cr.) at 2004-05 Prices',
#        'Industry (in Rs. Cr.) at 2004-05 Prices',
#        'Mining and Quarrying (in Rs. Cr.) at 2004-05 Prices',
#        'Manufacturing (in Rs. Cr.) at 2004-05 Prices',
#        'Services (in Rs. Cr.) at 2004-05 Prices',
#        'Agri-culture & Allied Services -Share to Total GDP',
#        'Agriculture - Share to Total GDP', 'Industry - Share to Total GDP',
#        'Mining and Quarrying - Share to Total GDP',
#        'Manufacturing - Share to Total GDP', 'Services - Share to Total GDP',
#        'Gross Domestic Product - % Growth Rate (YoY)',
#        'Agri-culture & Allied Services - % Growth Rate (YoY)',
#        'Agriculture - % Growth Rate (YoY)', 'Industry - % Growth Rate (YoY)',
#        'Mining and Quarrying - % Growth Rate (YoY)',
# ...

# %%
df.rename(columns={'Financial Year':'Year','Gross Domestic Product (in Rs. Cr) at 2004-05 Prices':'GDP in cr at 2004 price'},inplace = True)

# %%
df.columns
# Out:
# Index(['Year', 'GDP in cr at 2004 price',
#        'Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices',
#        'Agriculture (in Rs. Cr.) at 2004-05 Prices',
#        'Industry (in Rs. Cr.) at 2004-05 Prices',
#        'Mining and Quarrying (in Rs. Cr.) at 2004-05 Prices',
#        'Manufacturing (in Rs. Cr.) at 2004-05 Prices',
#        'Services (in Rs. Cr.) at 2004-05 Prices',
#        'Agri-culture & Allied Services -Share to Total GDP',
#        'Agriculture - Share to Total GDP', 'Industry - Share to Total GDP',
#        'Mining and Quarrying - Share to Total GDP',
#        'Manufacturing - Share to Total GDP', 'Services - Share to Total GDP',
#        'Gross Domestic Product - % Growth Rate (YoY)',
#        'Agri-culture & Allied Services - % Growth Rate (YoY)',
#        'Agriculture - % Growth Rate (YoY)', 'Industry - % Growth Rate (YoY)',
#        'Mining and Quarrying - % Growth Rate (YoY)',
#        'Manufacturing - % Growth Rate (YoY)',
# ...

# %%
df
# Out:
#        Year  GDP in cr at 2004 price  \
# 0   1951-52                   286147
# 1   1952-53                   294267
# 2   1953-54                   312177
# 3   1954-55                   325431
# 4   1955-56                   333766
# ..      ...                      ...
# 56  2007-08                  3896636
# 57  2008-09                  4158676
# 58  2009-10                  4516071
# 59  2010-11                  4937006
# 60  2011-12                  5243582
#
#     Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                              147216
# 1                                              151859
# 2                                              163553
# 3                                              168361
# 4                                              166906
# ..                                                ...
# 56                                             655080
# 57                                             655689
# ...

# %%
print(df.Year)
# Out:
# 0     1951-52
# 1     1952-53
# 2     1953-54
# 3     1954-55
# 4     1955-56
#        ...
# 56    2007-08
# 57    2008-09
# 58    2009-10
# 59    2010-11
# 60    2011-12
# Name: Year, Length: 61, dtype: object

# %%
df.describe()
# Out:
#        GDP in cr at 2004 price  \
# count             6.100000e+01
# mean              1.384075e+06
# std               1.255540e+06
# min               2.861470e+05
# 25%               4.882470e+05
# 50%               8.434260e+05
# 75%               1.876319e+06
# max               5.243582e+06
#
#        Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# count                                          61.000000
# mean                                       349045.344262
# std                                        165332.644862
# min                                        147216.000000
# 25%                                        214343.000000
# 50%                                        297293.000000
# 75%                                        478933.000000
# max                                        739495.000000
#
#        Agriculture (in Rs. Cr.) at 2004-05 Prices  \
# count                                   61.000000
# ...

# %%
Year = list(map(int, range(1951,2012)))

# %%
df.drop(columns = {'Year'},inplace = True)

# %%
df
# Out:
#     GDP in cr at 2004 price  \
# 0                    286147
# 1                    294267
# 2                    312177
# 3                    325431
# 4                    333766
# ..                      ...
# 56                  3896636
# 57                  4158676
# 58                  4516071
# 59                  4937006
# 60                  5243582
#
#     Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                              147216
# 1                                              151859
# 2                                              163553
# 3                                              168361
# 4                                              166906
# ..                                                ...
# 56                                             655080
# 57                                             655689
# 58                                             660987
# 59                                             713477
# ...

# %%
df['Year'] = np.array(Year)

# %%
df
# Out:
#     GDP in cr at 2004 price  \
# 0                    286147
# 1                    294267
# 2                    312177
# 3                    325431
# 4                    333766
# ..                      ...
# 56                  3896636
# 57                  4158676
# 58                  4516071
# 59                  4937006
# 60                  5243582
#
#     Agriculture & Allied Services (in Rs. Cr.) at 2004-05 Prices  \
# 0                                              147216
# 1                                              151859
# 2                                              163553
# 3                                              168361
# 4                                              166906
# ..                                                ...
# 56                                             655080
# 57                                             655689
# 58                                             660987
# 59                                             713477
# ...

# %%
df_gdp = df[['Year','GDP in cr at 2004 price']]

# %%
df_gdp
# Out:
#     Year  GDP in cr at 2004 price
# 0   1951                   286147
# 1   1952                   294267
# 2   1953                   312177
# 3   1954                   325431
# 4   1955                   333766
# ..   ...                      ...
# 56  2007                  3896636
# 57  2008                  4158676
# 58  2009                  4516071
# 59  2010                  4937006
# 60  2011                  5243582
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Plotting the Dataset
#
# This is what the datapoints look like. It kind of looks like an exponential function. The growth starts off slow, then from 1990 forward, the growth is very significant; as illustrated below.

# %%
plt.figure(figsize =(8,5))
x_data, y_data = (df_gdp['Year'].values, df_gdp['GDP in cr at 2004 price'].values)
plt.plot(x_data, y_data)
plt.ylabel('GDP in cr at 2004 price')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Choosing a model
#
# From an initail look we determine that the exponential function could be a good approximation, since it has the property of starting with a slow growth, and then increasing significantly.

# %%
X = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

Y= -23.490223 * (-8.869675 * np.exp(X))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %% [markdown]
# ### Building The Model
#
# Now, let's build our regression model and initailize its parameters.

# %%
def expo(x, a,b,c):
     return a * np.exp(b * x) + c

# %% [markdown]
# Our task here is to find the best parameters for our model. Let's first normalize our x and y.

# %%
# Let's normalize our data
xdata = x_data/ max(x_data)
ydata = y_data/max(y_data)

# %% [markdown]
# #### How we find the best paramets for our fit line?
#
# We can use curve_fit which uses non-linear least squares to fit our sigmoidal function, to data. Optimal values for the parameters so that the sum of the squared residuals of sigmoid(xdata*popt) - ydata is minimized.
#
# popt are optimized parameters.

# %%
from scipy.optimize import curve_fit

# %%
popt, pcov = curve_fit(expo, xdata, ydata, maxfev = 10000)

# Print the final parameters
print(" a = %f, b = %f, c= %f" % (popt[0], popt[1],popt[2]))
# Out:
#  a = 0.000000, b = 157.164110, c= 0.065136

# %% [markdown]
# Now we plot our resulting regression model.

# %%
x = np.linspace(1951, 2012, 61)
x = x/max(x)
plt.figure(figsize=(8,5))
y = expo(x,*popt)

plt.plot(xdata, ydata, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
train_x = xdata[msk]
test_x = xdata[~msk]
train_y = ydata[msk]
test_y = ydata[~msk]

# %%
popt, pcov = curve_fit(expo, train_x, train_y,maxfev = 20000)

# %%
y_hat = expo(test_x, *popt)

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((y_hat - test_y) ** 2))
from sklearn.metrics import r2_score
print("R2-score: %.2f" % r2_score(y_hat , test_y) )
# Out:
# Mean absolute error: 0.01
# Residual sum of squares (MSE): 0.00
# R2-score: 0.98

# %% [markdown]
# Looking at the $R^2$ score we can say that our model is pretty much good.
